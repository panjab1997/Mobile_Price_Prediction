# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns 

import warnings
from scipy import stats
import statsmodels.api as sm

# %%
df = pd.read_csv('Mobile_data.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   battery_power  2000 non-null   int64
#  1   clock_speed    2000 non-null   float64
#  2   fc             2000 non-null   int64
#  3   int_memory     2000 non-null   int64
#  4   m_dep          2000 non-null   float64
#  5   mobile_wt      2000 non-null   int64
#  6   n_cores        2000 non-null   int64
#  7   pc             2000 non-null   int64
#  8   px_height      2000 non-null   int64
#  9   px_width       2000 non-null   int64
#  10  ram            2000 non-null   int64
#  11  sc_h           2000 non-null   int64
#  12  sc_w           2000 non-null   int64
#  13  talk_time      2000 non-null   int64
#  14  price_range    2000 non-null   int64
# dtypes: float64(2), int64(13)
# memory usage: 234.5 KB

# %%
df.isnull().sum()
# Out:
# battery_power    0
# clock_speed      0
# fc               0
# int_memory       0
# m_dep            0
# mobile_wt        0
# n_cores          0
# pc               0
# px_height        0
# px_width         0
# ram              0
# sc_h             0
# sc_w             0
# talk_time        0
# price_range      0
# dtype: int64

# %%
df.describe()
# Out:
#        battery_power  clock_speed           fc   int_memory        m_dep  \
# count    2000.000000  2000.000000  2000.000000  2000.000000  2000.000000
# mean     1238.518500     1.522250     4.309500    32.046500     0.501750
# std       439.418206     0.816004     4.341444    18.145715     0.288416
# min       501.000000     0.500000     0.000000     2.000000     0.100000
# 25%       851.750000     0.700000     1.000000    16.000000     0.200000
# 50%      1226.000000     1.500000     3.000000    32.000000     0.500000
# 75%      1615.250000     2.200000     7.000000    48.000000     0.800000
# max      1998.000000     3.000000    19.000000    64.000000     1.000000
#
#          mobile_wt      n_cores           pc    px_height     px_width  \
# count  2000.000000  2000.000000  2000.000000  2000.000000  2000.000000
# mean    140.249000     4.520500     9.916500   645.108000  1251.515500
# std      35.399655     2.287837     6.064315   443.780811   432.199447
# ...

# %% [markdown]
# ## price_range (target)

# %%
df.price_range.value_counts()
# Out:
# 1    500
# 2    500
# 3    500
# 0    500
# Name: price_range, dtype: int64

# %%
sns.countplot(data = df , x = 'price_range')

plt.title("Count Plot of Every Price Range")
# Out:
# Text(0.5, 1.0, 'Count Plot of Every Price Range')

# %% [markdown]
# ## 1) battery_power

# %%
df.battery_power.dtype
# Out:
# dtype('int64')

# %%
sns.displot(data = df , x = 'battery_power')
plt.title('battery_power Data Distribution Plot')
# Out:
# Text(0.5, 1.0, 'battery_power Data Distribution Plot')

# %%
sns.boxplot(data = df , x = 'battery_power' , palette= 'dark')
# Out:
# <AxesSubplot: xlabel='battery_power'>

# %%
sns.scatterplot(data = df , x = 'battery_power' , y = 'price_range')
# Out:
# <AxesSubplot: xlabel='battery_power', ylabel='price_range'>

# %% [markdown]
# ## 2) clock_speed

# %%
df.clock_speed.dtype
# Out:
# dtype('float64')

# %%
sns.displot(data = df , x = 'clock_speed' , palette='muted')
plt.title('clock_speed Data Distribution Plot')
# Out:
# Text(0.5, 1.0, 'clock_speed Data Distribution Plot')

# %%
sns.boxplot(data = df , x = 'clock_speed',palette='pastel')
# Out:
# <AxesSubplot: xlabel='clock_speed'>

# %%
sns.scatterplot(data = df , x = 'clock_speed' , y = 'price_range')
# Out:
# <AxesSubplot: xlabel='clock_speed', ylabel='price_range'>

# %% [markdown]
# ## 3) fc

# %%
df.fc.dtype
# Out:
# dtype('int64')

# %%
sns.displot(data = df , x = 'fc')
plt.title('Front_camera pix Data Distribution Plot')
# Out:
# Text(0.5, 1.0, 'Front_camera pix Data Distribution Plot')

# %%
sns.boxplot(data = df , x = 'fc',palette='deep')
# Out:
# <AxesSubplot: xlabel='fc'>

# %%
sns.scatterplot(data = df , x = 'fc' , y = 'price_range')
# Out:
# <AxesSubplot: xlabel='fc', ylabel='price_range'>

# %% [markdown]
# ## 4) int_memory

# %%
df.int_memory.dtype
# Out:
# dtype('int64')

# %%
sns.displot(data = df , x = 'int_memory')
plt.title('Internal Memory Data Distribution Plot')
# Out:
# Text(0.5, 1.0, 'Internal Memory Data Distribution Plot')

# %%
sns.boxplot(data = df , x = 'int_memory' , palette='dark')
# Out:
# <AxesSubplot: xlabel='int_memory'>

# %% [markdown]
# ## 5) m_dep

# %%
sns.displot(data = df , x = 'm_dep')
plt.title('Mobile Depth Data Distribution Plot')
# Out:
# Text(0.5, 1.0, 'Mobile Depth Data Distribution Plot')

# %%
sns.boxplot(data = df , x = 'm_dep')
# Out:
# <AxesSubplot: xlabel='m_dep'>

# %% [markdown]
# ## 6) mobile_wt

# %%
sns.displot(data = df , x = 'mobile_wt')
plt.title('Mobile weight Data Distribution Plot')
# Out:
# Text(0.5, 1.0, 'Mobile weight Data Distribution Plot')

# %%
sns.boxplot(data = df , x = 'mobile_wt' , color='g')
# Out:
# <AxesSubplot: xlabel='mobile_wt'>

# %% [markdown]
# ## 7) n_cores

# %%
sns.displot(data = df , x = 'n_cores')
plt.title('Number of cores of a processor Data Distribution Plot')
# Out:
# Text(0.5, 1.0, 'Number of cores of a processor Data Distribution Plot')

# %%
sns.boxplot(data = df , x = 'n_cores', color='r')
# Out:
# <AxesSubplot: xlabel='n_cores'>

# %%
sns.scatterplot(data = df , x = 'n_cores' , y = 'price_range')
# Out:
# <AxesSubplot: xlabel='n_cores', ylabel='price_range'>

# %% [markdown]
# ## 8) pc

# %%
sns.displot(data = df , x = 'pc')
plt.title('Primary Camera megapixels Distribution')
# Out:
# Text(0.5, 1.0, 'Primary Camera megapixels Distribution')

# %%
sns.boxplot(data = df , x ='pc' , color='y')
# Out:
# <AxesSubplot: xlabel='pc'>

# %% [markdown]
# ## 9) px_height

# %%
sns.displot(data = df , x = 'px_height')
plt.title('Pixel Resolution Height Distribution')
# Out:
# Text(0.5, 1.0, 'Pixel Resolution Height Distribution')

# %%
sns.boxplot(data = df , x = 'px_height' , palette='deep')
# Out:
# <AxesSubplot: xlabel='px_height'>

# %%
sns.scatterplot(data = df , x = 'px_height' , y = 'price_range')
# Out:
# <AxesSubplot: xlabel='px_height', ylabel='price_range'>

# %% [markdown]
# ## 10) px_width

# %%
sns.displot(data = df , x = 'px_width')
plt.title('Pixel Resolution Width Distribution')
# Out:
# Text(0.5, 1.0, 'Pixel Resolution Width Distribution')

# %%
sns.boxplot(data = df , x = 'px_width')
# Out:
# <AxesSubplot: xlabel='px_width'>

# %% [markdown]
# ## 11) ram

# %%
sns.displot(data = df , x = 'ram')
plt.title('RAM Distribution Plot')
# Out:
# Text(0.5, 1.0, 'RAM Distribution Plot')

# %%
sns.boxplot(data = df , x = 'ram' , palette='deep')
# Out:
# <AxesSubplot: xlabel='ram'>

# %%
sns.scatterplot(data = df , x = 'ram' , y = 'price_range' , palette='dark')
plt.title('Price Range vs RAM')
# Out:
# Text(0.5, 1.0, 'Price Range vs RAM')

# %% [markdown]
# ## 12) sc_h

# %%
sns.displot(data = df , x = 'sc_h')
plt.title('Screen Height of mobile Distribution')
# Out:
# Text(0.5, 1.0, 'Screen Height of mobile Distribution')

# %%
sns.boxplot(data = df , x = 'sc_h')
# Out:
# <AxesSubplot: xlabel='sc_h'>

# %%
sns.scatterplot(data = df , x = 'sc_h' , y = 'price_range')
# Out:
# <AxesSubplot: xlabel='sc_h', ylabel='price_range'>

# %% [markdown]
# ## 13) sc_w

# %%
sns.displot(data = df , x = 'sc_w')
plt.title('Screen Width of mobile(cm) Distribution')
# Out:
# Text(0.5, 1.0, 'Screen Width of mobile(cm) Distribution')

# %%
sns.boxplot(data = df , x = 'sc_w' , color='r')
# Out:
# <AxesSubplot: xlabel='sc_w'>

# %%
sns.scatterplot(data = df , x = 'sc_w' , y = 'price_range')
# Out:
# <AxesSubplot: xlabel='sc_w', ylabel='price_range'>

# %% [markdown]
# ## 14) talk_time

# %%
sns.displot(data = df , x = 'talk_time')
plt.title('Talk Time Distribution Plot')
# Out:
# Text(0.5, 1.0, 'Talk Time Distribution Plot')

# %%
sns.boxplot(data = df , x = 'talk_time',palette='dark')
# Out:
# <AxesSubplot: xlabel='talk_time'>

# %% [markdown]
# # Models

# %%
## #Assigning Predictors & Target Variable

X = df.iloc[:,:-1] #14 Variables
print(X.info())
y = df.iloc[:,-1]
y.sample(frac = 0.01)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   battery_power  2000 non-null   int64
#  1   clock_speed    2000 non-null   float64
#  2   fc             2000 non-null   int64
#  3   int_memory     2000 non-null   int64
#  4   m_dep          2000 non-null   float64
#  5   mobile_wt      2000 non-null   int64
#  6   n_cores        2000 non-null   int64
#  7   pc             2000 non-null   int64
#  8   px_height      2000 non-null   int64
#  9   px_width       2000 non-null   int64
#  10  ram            2000 non-null   int64
#  11  sc_h           2000 non-null   int64
#  12  sc_w           2000 non-null   int64
#  13  talk_time      2000 non-null   int64
# dtypes: float64(2), int64(12)
# memory usage: 218.9 KB
# None
# 1847    0
# 679     0
# 262     0
# 1665    1
# 565     0
# 1463    2
# 1248    0
# 1295    2
# 48      0
# ...

# %%
#Splitting the data
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y,random_state = 25,test_size=0.25)

len(X_train) #1500
len(X_test) #500
len(y_train) #1500
len(y_test) #500
# Out:
# 500

# %%
#Building Model @ n_neighbors = 13
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors = 13)
print(knn) 
df_knn = knn.fit(X_train, y_train) 
print(df_knn)
# Out:
# KNeighborsClassifier(n_neighbors=13)
# KNeighborsClassifier(n_neighbors=13)

# %%
#Applying on Test data for prediction
y_pred = df_knn.predict(X_test)
print(y_pred)
# Out:
# [1 1 3 0 1 1 0 2 0 3 1 0 1 1 1 2 1 2 3 0 1 1 2 0 2 3 1 0 3 0 3 1 2 0 2 3 0
#  1 2 0 1 2 3 2 3 1 0 3 1 2 3 0 0 3 0 3 1 0 0 0 1 2 2 0 3 1 1 0 1 2 0 1 0 3
#  3 1 3 2 1 3 0 3 0 0 0 0 2 2 2 3 3 2 3 3 2 3 1 2 2 2 1 2 1 2 2 3 2 3 2 0 1
#  1 1 1 1 1 0 3 2 1 3 2 2 2 2 2 2 1 3 2 1 2 0 2 3 1 1 1 2 0 2 3 2 3 1 1 1 0
#  2 1 3 2 0 2 1 1 0 2 1 2 3 1 1 0 2 0 2 2 2 0 0 2 2 2 2 2 3 1 0 3 0 0 1 1 0
#  2 2 2 1 3 3 2 2 2 1 1 0 3 3 2 3 0 0 1 0 0 2 3 3 1 2 1 0 2 2 1 1 1 1 0 1 0
#  1 0 0 3 3 1 1 3 2 0 3 3 2 3 1 3 1 3 1 0 1 2 0 1 3 3 2 0 0 0 3 2 2 3 2 3 1
#  2 1 3 3 0 3 1 0 2 0 1 1 0 1 2 0 2 2 2 1 3 0 0 0 1 2 3 3 3 1 0 3 1 0 1 0 0
#  0 2 1 1 2 3 2 2 0 0 0 3 1 0 2 2 3 3 1 0 3 0 0 0 1 3 2 0 1 2 3 3 1 2 2 1 2
#  1 2 0 0 0 1 1 3 2 0 3 2 0 3 1 3 2 1 1 2 1 0 3 2 1 2 1 0 1 3 2 3 1 2 1 2 0
#  0 3 2 1 1 2 1 2 1 2 0 3 0 2 3 0 2 0 3 1 1 0 0 1 3 2 3 3 2 2 2 1 2 2 3 0 0
#  2 1 1 1 1 1 2 3 2 3 3 3 1 2 3 3 1 2 1 3 2 2 3 3 3 1 3 1 0 3 3 0 2 0 1 0 0
# ...

# %%
#Prediction Score
df_knn.score(X_test, y_test) #0.948
# Out:
# 0.948

# %%
#Accuracy Score
from sklearn.metrics import accuracy_score
accuracy_score(y_test, y_pred) #94.8
# Out:
# 0.948

# %%
#Classification Matrix
pd.crosstab(y_test, y_pred, margins = True, rownames=['Actual'], colnames=['Predict'])
# Out:
# Predict    0    1    2    3  All
# Actual
# 0        121    4    0    0  125
# 1          3  119    1    0  123
# 2          0    8  122    4  134
# 3          0    0    6  112  118
# All      124  131  129  116  500

# %%
#Classification Report
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.97      0.97       125
#            1       0.91      0.97      0.94       123
#            2       0.95      0.91      0.93       134
#            3       0.97      0.95      0.96       118
#
#     accuracy                           0.95       500
#    macro avg       0.95      0.95      0.95       500
# weighted avg       0.95      0.95      0.95       500

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
#________________________________________find optimal number of n_neigbors
error_rate = [] #an empty list
  
# Will take some time 
for i in range(1, 40): 
      
    knn = KNeighborsClassifier(n_neighbors = i) 
    knn.fit(X_train, y_train) 
    pred_i = knn.predict(X_test) 
    error_rate.append(np.mean(pred_i != y_test))

# %%
plt.figure(figsize =(10, 6)) 
plt.plot(range(1, 40), error_rate, color ='blue', 
                linestyle ='dotted', marker ='o', 
         markerfacecolor ='red', markersize = 10) 
plt.title('Error Rate vs. n_neighbors') 
plt.xlabel('n_neighbors') 
plt.ylabel('Error Rate')
# Out:
# Text(0, 0.5, 'Error Rate')

# %% [markdown]
# # '''n_neighbor value with least error is the optimal value of n_neighbor'''
#  ## in this case 13 is the answer.
